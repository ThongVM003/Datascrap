# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("diem_thi_thpt_2022.csv")
df.head()
# Out:
#        sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  lich_su  \
# 0  1000001   3.6     5.00        4.0     NaN      NaN       NaN     2.75
# 1  1000002   8.4     6.75        7.6     NaN      NaN       NaN     8.50
# 2  1000003   5.8     7.50        5.0     NaN      NaN       NaN     7.25
# 3  1000004   7.4     7.50        8.6     NaN      NaN       NaN     7.50
# 4  1000005   7.2     8.50        9.0     NaN      NaN       NaN     8.00
#
#    dia_li  gdcd
# 0     6.0  8.75
# 1     7.5  8.25
# 2     5.5  8.75
# 3     6.5  7.50
# 4     8.5  8.25

# %%
with open("data.txt","r",encoding="utf-8") as f:
    d = [None]
    for i in f:
        it = i.strip().split("\t")
        d.append(it[1])
d
# Out:
# [None,
#  'Sở GDĐT Hà Nội',
#  'Sở GDĐT TP. Hồ Chí Minh',
#  'Sở GDĐT Hải Phòng',
#  'Sở GDĐT Đà Nẵng',
#  'Sở GDĐT Hà Giang',
#  'Sở GDĐT Cao Bằng',
#  'Sở GDĐT Lai Châu',
#  'Sở GDĐT Lào Cai',
#  'Sở GDĐT Tuyên Quang',
#  'Sở GDĐT Lạng Sơn',
#  'Sở GDĐT Bắc Kạn',
#  'Sở GDĐT Thái Nguyên',
#  'Sở GDĐT Yên Bái',
#  'Sở GDĐT Sơn La',
#  'Sở GDĐT Phú Thọ',
#  'Sở GDĐT Vĩnh Phúc',
#  'Sở GDĐT Quảng Ninh',
#  'Sở GDĐT Bắc Giang',
#  'Sở GDĐT Bắc Ninh',
#  'Meo',
#  'Sở GDĐT Hải Dương',
#  'Sở GDĐT Hưng Yên',
#  'Sở GDĐT Hoà Bình',
#  'Sở GDĐT Hà Nam',
#  'Sở GDĐT Nam Định',
#  'Sở GDĐT Thái Bình',
#  'Sở GDĐT Ninh Bình',
#  'Sở GDĐT Thanh Hoá',
#  'Sở GDĐT Nghệ An',
#  'Sở GDĐT Hà Tĩnh',
#  'Sở GDĐT Quảng Bình',
#  'Sở GDĐT Quảng Trị',
#  'Sở GDĐT Thừa Thiên -Huế',
#  'Sở GDĐT Quảng Nam',
#  'Sở GDĐT Quảng Ngãi',
#  'Sở GDĐT Kon Tum',
#  'Sở GDĐT Bình Định',
#  'Sở GDĐT Gia Lai',
#  'Sở GDĐT Phú Yên',
#  'Sở GDĐT Đắk Lắk',
#  'Sở GDĐT Khánh Hoà',
#  'Sở GDĐT Lâm Đồng',
# ...

# %%
df["hoi_dong"] = df["sbd"].apply(lambda x: d[int(f'{x:08n}'[:2])])
# print(len(d))
df["ma_tinh"] = df["sbd"].apply(lambda x: int(f'{x:08n}'[:2]))
df
# Out:
#              sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  \
# 0        1000001   3.6     5.00        4.0     NaN      NaN       NaN
# 1        1000002   8.4     6.75        7.6     NaN      NaN       NaN
# 2        1000003   5.8     7.50        5.0     NaN      NaN       NaN
# 3        1000004   7.4     7.50        8.6     NaN      NaN       NaN
# 4        1000005   7.2     8.50        9.0     NaN      NaN       NaN
# ...          ...   ...      ...        ...     ...      ...       ...
# 995436  64006584   8.4     6.75        4.6     NaN      NaN       NaN
# 995437  64006585   5.6     6.50        2.8     NaN      NaN       NaN
# 995438  64006586   5.8     6.00        6.6     NaN      NaN       NaN
# 995439  64006587   7.6     6.75        7.0     NaN      NaN       NaN
# 995440  64006588   6.6     4.50        3.2     NaN      NaN       NaN
#
#         lich_su  dia_li  gdcd           hoi_dong  ma_tinh
# 0          2.75    6.00  8.75     Sở GDĐT Hà Nội        1
# ...

# %%
df.to_csv("new.csv", index=False)
